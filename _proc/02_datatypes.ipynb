# %% [raw]
# ---
# description: Classes para modelar as diferentes estruturas de dados a serem enviadas
#   para o Redmine
# output-file: datatypes.html
# title: Datatypes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(AtomicField)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/fiscaliza/blob/main/fiscaliza/datatypes.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### AtomicField
#
# >      AtomicField (name:str, keyword:str, mandatory:bool=True)

# %%
#| echo: false
#| output: asis
show_doc(SimpleField)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/fiscaliza/blob/main/fiscaliza/datatypes.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### SimpleField
#
# >      SimpleField (id:int, name:str, mandatory:bool=False, multiple:bool=False,
# >                   format_value:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(EncodedString)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/fiscaliza/blob/main/fiscaliza/datatypes.py#L76){target="_blank" style="float:right; font-size:smaller"}
#
# ### EncodedString
#
# >      EncodedString (id:int, name:str, mandatory:bool=False,
# >                     multiple:bool=False, format_value:bool=False)
#
# *This class always format the value string
# The json key is called 'numero'*

# %%
#| echo: false
#| output: asis
show_doc(FieldWithOptions)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/fiscaliza/blob/main/fiscaliza/datatypes.py#L97){target="_blank" style="float:right; font-size:smaller"}
#
# ### FieldWithOptions
#
# >      FieldWithOptions (id:int, name:str, mandatory:bool=False,
# >                        multiple:bool=False, format_value:bool=False,
# >                        options:list[str]=None, mapping:dict[str,list]=None)

# %%
#| echo: false
#| output: asis
show_doc(Coordenadas)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/fiscaliza/blob/main/fiscaliza/datatypes.py#L141){target="_blank" style="float:right; font-size:smaller"}
#
# ### Coordenadas
#
# >      Coordenadas (id:int, name:str, mandatory:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(GerarPlai)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/fiscaliza/blob/main/fiscaliza/datatypes.py#L172){target="_blank" style="float:right; font-size:smaller"}
#
# ### GerarPlai
#
# >      GerarPlai (id:int, name:str, mandatory:bool=False)
